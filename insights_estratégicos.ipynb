# %%
# 📊 Análise Exploratória de Produtos - Dataset Tratado

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carregar os dados
caminho_arquivo = 'Dados_tratados.csv'
df = pd.read_csv("data/Dados_tratados.csv")

# -----------------------------------------------
# 🔍 Etapa 1: Correlação entre Variáveis Numéricas
# -----------------------------------------------
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Matriz de Correlação entre Variáveis Numéricas")
plt.show()

# ---------------------------------------------------------
# 🔎 Etapa 2: Produtos com Alta Nota e Poucas Avaliações
# ---------------------------------------------------------
produtos_ocultos = df[(df['Nota'] >= 4.5) & (df['N_Avaliações'] < 10)]

# Visualizar os principais produtos com esse perfil
print("Produtos com Nota >= 4.5 e N_Avaliações < 10:")
print(produtos_ocultos[['Título', 'Nota', 'N_Avaliações', 'Qtd_Vendidos', 'Preço']].sort_values(by='Nota', ascending=False))

# Gráfico de dispersão
plt.figure(figsize=(10, 6))
sns.scatterplot(data=produtos_ocultos, x='Preço', y='Nota', hue='Qtd_Vendidos', palette='viridis', size='N_Avaliações', sizes=(40, 200))
plt.title('Produtos Bem Avaliados com Poucas Vendas')
plt.xlabel('Preço')
plt.ylabel('Nota')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.tight_layout()
plt.show()

# ------------------------------------------------
# 📌 Ações Estratégicas Recomendadas (Resumo Final)
# ------------------------------------------------
acoes = """
🎯 Ações Estratégicas Recomendadas:

1. ✅ Reforçar o marketing de produtos bem avaliados com poucas avaliações (potencial escondido).
2. 📦 Aumentar o estoque dos produtos com muitas vendas e avaliações positivas.
3. 📢 Investir em campanhas promocionais nas categorias mais populares.
4. 🕵️ Explorar padrões sazonais ou impacto dos descontos para ajustar estratégias de preço.
5. 🛍️ Verificar se produtos com preço alto possuem avaliações ruins – pode indicar necessidade de ajustes.
"""

print(acoes)
# Out:
# Produtos com Nota >= 4.5 e N_Avaliações < 10:
#                                                  Título  Nota  N_Avaliações  \
# 55     Calça Jeans Levis 511 Original Slim Fit Elastano   5.0           3.0
# 64    Roupas Femininas Bermuda Feminina Sarja Bolso ...   5.0           6.0
# 1877    Conjunto De Ballet Collant E Saia Cós Body Rosa   5.0           2.0
# 1878  Kit C/ 10 Short Segunda Pele Para Usar Com Rou...   5.0           1.0
# 1880  3 Conjunto Short Saia Rodado Top Tapa Bumbum R...   5.0           4.0
# ...                                                 ...   ...           ...
# 418   Faixa De Cabeça Fina On/off (thin Headband) Co...   4.5           2.0
# 426   Bermudas Cós Alto Com Elastano Até O Joelho Ro...   4.5           4.0
# 273   60 Separadores De Roupas Numerador Araras Sem ...   4.5           4.0
# 166   Calça Oxford Branco Elastico Umbanda Açougue R...   4.5           2.0
# 1936  Short Masculino Malha Colorblock Aeroready adi...   4.5           8.0
#
# ...
